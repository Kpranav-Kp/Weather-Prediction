# %%
import pandas as pd

# %%
weather = pd.read_csv("weather_data_35_years.csv", index_col="time")

# %%
weather
# Out:
#             temperature_2m_max (°C)  temperature_2m_min (°C)  \
# time
# 1990-01-01                     26.6                     23.5
# 1990-01-02                     27.1                     22.4
# 1990-01-03                     27.4                     22.5
# 1990-01-04                     26.9                     23.1
# 1990-01-05                     26.8                     22.2
# ...                             ...                      ...
# 2025-06-27                     37.4                     28.1
# 2025-06-28                     37.3                     28.9
# 2025-06-29                     39.7                     29.0
# 2025-06-30                     37.9                     29.1
# 2025-07-01                     37.2                     27.6
#
#             weather_code (wmo code)  wind_speed_10m_max (km/h)  \
# time
# 1990-01-01                       51                       17.2
# 1990-01-02                       51                       17.4
# ...

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# temperature_2m_max (°C)           0.0
# temperature_2m_min (°C)           0.0
# weather_code (wmo code)           0.0
# wind_speed_10m_max (km/h)         0.0
# cloud_cover_mean (%)              0.0
# relative_humidity_2m_mean (%)     0.0
# pressure_msl_mean (hPa)           0.0
# cloud_cover_max (%)               0.0
# dew_point_2m_mean (°C)            0.0
# temperature_2m_mean (°C)          0.0
# apparent_temperature_mean (°C)    0.0
# wind_speed_10m_mean (km/h)        0.0
# precipitation_sum (mm)            0.0
# dtype: float64

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2025-06-22', '2025-06-23', '2025-06-24', '2025-06-25',
#                '2025-06-26', '2025-06-27', '2025-06-28', '2025-06-29',
#                '2025-06-30', '2025-07-01'],
#               dtype='datetime64[ns]', name='time', length=12966, freq=None)

# %%
weather["target"] = weather.shift(-1)["weather_code (wmo code)"]
weather = weather.iloc[:-1,:].copy()
weather["target"] = weather["target"].astype(int)

# %%
import matplotlib.pyplot as plt

weather["target"].value_counts().sort_index().plot(kind='bar', figsize=(8,4), title="Target Weather Code Frequency")
plt.xlabel("WMO Code")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
train = weather.loc[:"2017-05-31"]

# %%
test = weather.loc["2017-06-01":]

# %%
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.utils.class_weight import compute_sample_weight

target_col = 'target'

X_train = train.drop(columns=[target_col])
y_train = train[target_col]

X_test = test.drop(columns=[target_col])
y_test = test[target_col]

le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)

sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_enc)
xgb_model = XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    tree_method='hist',
    eval_metric='mlogloss'
)

xgb_model.fit(X_train, y_train_enc, sample_weight=sample_weights)
y_pred_enc = xgb_model.predict(X_test)
y_pred = le.inverse_transform(y_pred_enc)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        12
#            1       0.09      0.22      0.13        76
#            2       0.15      0.48      0.23       126
#            3       0.55      0.35      0.43       817
#           51       0.42      0.29      0.34       778
#           53       0.15      0.15      0.15       291
#           55       0.06      0.08      0.07       109
#           61       0.19      0.33      0.24       257
#           63       0.40      0.39      0.40       403
#           65       0.18      0.04      0.06        83
#
#     accuracy                           0.30      2952
#    macro avg       0.22      0.23      0.20      2952
# weighted avg       0.36      0.30      0.32      2952

# %%
from xgboost import plot_importance
plot_importance(xgb_model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE  # optional, for balancing

# ---------------------------
# 1. Split by date
# ---------------------------
train = weather.loc[:"2017-05-31"]
test = weather.loc["2017-06-01":]

# ---------------------------
# 2. Separate features & target
# ---------------------------
X_train = train.drop(columns=["target"])
y_train = train["target"]

X_test = test.drop(columns=["target"])
y_test = test["target"]

# ---------------------------
# 3. Encode target labels
# ---------------------------
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

# ---------------------------
# 4. Optional: Balance classes
# ---------------------------
balance_data = True
if balance_data:
    smote = SMOTE(random_state=42)
    X_train, y_train_enc = smote.fit_resample(X_train, y_train_enc)

# ---------------------------
# 5. Train XGBoost
# ---------------------------
model = XGBClassifier(
    eval_metric="mlogloss",
    random_state=42,
    use_label_encoder=False
)
model.fit(X_train, y_train_enc)

# ---------------------------
# 6. Predict & decode
# ---------------------------
y_pred_enc = model.predict(X_test)
y_pred = encoder.inverse_transform(y_pred_enc)

# ---------------------------
# 7. Evaluation
# ---------------------------
print("Classification Report (Encoded labels):")
print(classification_report(y_test_enc, y_pred_enc, target_names=[str(c) for c in encoder.classes_]))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test_enc, y_pred_enc))

# If you want original WMO codes in predictions:
pred_results = pd.DataFrame({
    "True_Code": y_test.values,
    "Pred_Code": y_pred
})
print("\nSample predictions:")
print(pred_results.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 5
#       3 from sklearn.metrics import classification_report, confusion_matrix
#       4 from xgboost import XGBClassifier
# ----> 5 from imblearn.over_sampling import SMOTE  # optional, for balancing
#       7 # ---------------------------
#       8 # 1. Split by date
#       9 # ---------------------------
#      10 train = weather.loc[:"2017-05-31"]
#
# ModuleNotFoundError: No module named 'imblearn'
